# %% [markdown]
# <a href="https://colab.research.google.com/github/Muasya0254/WK2-Practice---Data-Collection-and-Cleaning/blob/main/corona_virus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
virus = pd.read_csv('/content/corona_virus.csv', encoding="unicode_escape")
virus.head()
# Out:
#   Country,Other   Total Cases New Cases Total Deaths  New Deaths  \
# 0           USA  10,66,27,427       NaN    11,59,824         NaN
# 1         India   4,49,39,515       NaN     5,31,508         NaN
# 2        France   3,99,80,570       NaN     1,66,556         NaN
# 3       Germany   3,84,03,667       NaN     1,73,044         NaN
# 4        Brazil   3,74,49,418       NaN     7,01,494         NaN
#
#   Total Recovered New Recovered Active Cases Serious,Critical  \
# 0    10,45,49,551           NaN     9,18,052            1,368
# 1     4,43,56,693           NaN       51,314              NaN
# 2     3,96,77,000           NaN     1,37,014              869
# 3     3,81,92,900           600       37,723              NaN
# 4     3,62,49,161           NaN     4,98,763              NaN
#
#   Tot Cases/1M pop Deaths/1M pop     Total Tests Tests/1M pop      Population
# 0         3,18,476         3,464  1,17,68,34,935    35,14,983    33,48,05,269
# 1           31,948           378    92,64,96,579     6,58,663  1,40,66,31,776
# 2         6,09,604         2,540    27,14,90,188    41,39,547     6,55,84,518
# 3         4,57,821         2,063    12,23,32,384    14,58,359     8,38,83,596
# 4         1,73,897         3,257     6,37,76,166     2,96,146    21,53,53,593

# %%
virus.describe()
# Out:
#        New Deaths
# count         2.0
# mean          3.0
# std           0.0
# min           3.0
# 25%           3.0
# 50%           3.0
# 75%           3.0
# max           3.0

# %%
virus.shape # to check the dimension of the dataset
# Out:
# (232, 14)

# %%
# checking missing values
virus.isnull()
# Out:
#      Country,Other  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0            False        False       True         False        True
# 1            False        False       True         False        True
# 2            False        False       True         False        True
# 3            False        False       True         False        True
# 4            False        False       True         False        True
# ..             ...          ...        ...           ...         ...
# 227          False        False       True          True        True
# 228          False        False       True         False        True
# 229          False        False       True         False        True
# 230          False        False       True          True        True
# 231          False        False      False         False       False
#
#      Total Recovered  New Recovered  Active Cases  Serious,Critical  \
# 0              False           True         False             False
# 1              False           True         False              True
# 2              False           True         False             False
# 3              False          False         False              True
# 4              False           True         False              True
# ..               ...            ...           ...               ...
# 227            False           True         False              True
# 228            False           True         False              True
# 229            False           True         False              True
# 230             True           True         False              True
# 231            False          False         False             False
#
#      Tot Cases/1M pop  Deaths/1M pop  Total Tests  Tests/1M pop  Population
# 0               False          False        False         False       False
# 1               False          False        False         False       False
# 2               False          False        False         False       False
# 3               False          False        False         False       False
# 4               False          False        False         False       False
# ..                ...            ...          ...           ...         ...
# 227             False           True         True          True       False
# 228             False          False         True          True       False
# 229              True           True         True          True        True
# 230             False           True         True          True       False
# 231             False          False         True          True        True
#
# [232 rows x 14 columns]

# %% [markdown]
# **Check Missing Values**

# %%
# check missing by variables
virus.isnull().sum()
# Out:
# Country,Other         0
# Total Cases           0
# New Cases           227
# Total Deaths          6
# New Deaths          230
# Total Recovered      21
# New Recovered       220
# Active Cases         19
# Serious,Critical    105
# Tot Cases/1M pop      2
# Deaths/1M pop         8
# Total Tests          19
# Tests/1M pop         19
# Population            3
# dtype: int64

# %%
# Drop duplicate rows, keeping the first occurrence
virus.drop_duplicates(inplace=True)

# %% [markdown]
# **Fill missing values**

# %%
# fill missing values with 0
Fill_no = virus.fillna(0)
Fill_no.head()
# Out:
#   Country,Other   Total Cases New Cases Total Deaths  New Deaths  \
# 0           USA  10,66,27,427         0    11,59,824         0.0
# 1         India   4,49,39,515         0     5,31,508         0.0
# 2        France   3,99,80,570         0     1,66,556         0.0
# 3       Germany   3,84,03,667         0     1,73,044         0.0
# 4        Brazil   3,74,49,418         0     7,01,494         0.0
#
#   Total Recovered New Recovered Active Cases Serious,Critical  \
# 0    10,45,49,551             0     9,18,052            1,368
# 1     4,43,56,693             0       51,314                0
# 2     3,96,77,000             0     1,37,014              869
# 3     3,81,92,900           600       37,723                0
# 4     3,62,49,161             0     4,98,763                0
#
#   Tot Cases/1M pop Deaths/1M pop     Total Tests Tests/1M pop      Population
# 0         3,18,476         3,464  1,17,68,34,935    35,14,983    33,48,05,269
# 1           31,948           378    92,64,96,579     6,58,663  1,40,66,31,776
# 2         6,09,604         2,540    27,14,90,188    41,39,547     6,55,84,518
# 3         4,57,821         2,063    12,23,32,384    14,58,359     8,38,83,596
# 4         1,73,897         3,257     6,37,76,166     2,96,146    21,53,53,593
